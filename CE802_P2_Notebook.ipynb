# %%
import pandas as pd
from sklearn.model_selection import train_test_split

import numpy as np
from sklearn import preprocessing
from sklearn.impute import SimpleImputer


from sklearn.neighbors import KNeighborsClassifier

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score,cross_val_predict

from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.metrics import f1_score,confusion_matrix,accuracy_score,precision_score,recall_score

from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\Deepak Tripathi\Desktop\assignment machine learning\part2\CE802_P2_Data.csv")

# %%
df.head()
# Out:
#       F1    F2     F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 0   3.20 -4.91 -41.64 -21.63   8.41   2  5.42 -84.01  -9.40   76.72 -0.42
# 1   3.98 -5.25 -47.64 -23.43   8.66   2  4.32 -83.01 -11.16    2.72  0.50
# 2  12.60  0.41 -50.64 -15.51  16.34  20 -4.00  25.99 -15.08  450.72 -3.60
# 3  14.70  1.09 -50.64  -4.74  15.09  20 -8.16  10.99 -13.12  190.72 -5.71
# 4   2.74 -3.86 -35.64 -23.91   8.67   2  2.80 -53.01 -19.22   24.72  0.59
#
#    F12   F13    F14   F15  Class
# 0   36  0.33  30.60   NaN  False
# 1  111  0.84  39.42  9.26   True
# 2  525  5.10  21.78   NaN  False
# 3  660  7.25  15.78  6.57  False
# 4   33  0.85  25.08   NaN   True

# %%
df.describe()
# Out:
#                F1           F2           F3           F4           F5  \
# count  1500.00000  1500.000000  1500.000000  1500.000000  1500.000000
# mean      9.93752    -2.668787   -58.554000   -14.751160    11.477813
# std       8.65042     2.540644    21.477945     7.541549     3.166909
# min       0.00000   -11.700000  -110.640000   -37.740000     7.790000
# 25%       2.48000    -4.550000   -80.640000   -20.580000     8.510000
# 50%       4.14000    -3.650000   -47.640000   -17.700000     8.870000
# 75%      16.40000    -0.190000   -41.640000    -7.530000    14.240000
# max      31.40000     1.990000   -32.640000    -1.320000    17.940000
#
#                 F6           F7           F8           F9          F10  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     10.806667    -1.270267   -64.596000   -11.144707   139.610667
# std       9.009814     5.090345    40.188448     2.217929   142.833748
# ...

# %%
df['Class'].value_counts()
# Out:
# False    809
# True     691
# Name: Class, dtype: int64

# %% [markdown]
# # Data is little imbalanced and half of the values in F15 column are missing

# %%
df.shape
# Out:
# (1500, 16)

# %%
df.isnull().any()
# Out:
# F1       False
# F2       False
# F3       False
# F4       False
# F5       False
# F6       False
# F7       False
# F8       False
# F9       False
# F10      False
# F11      False
# F12      False
# F13      False
# F14      False
# F15       True
# Class    False
# dtype: bool

# %% [markdown]
# # Start building a very basic model without much preprocessing

# %% [markdown]
# # Try removing F15 as it contains null values and fit models

# %%
x1=df.drop(['F15','Class'],axis=1)
y1=df['Class']

x, X_test, y, y_test = train_test_split(x1, y1, test_size=0.20, random_state=42)

algo=pd.DataFrame(columns=['Accuracy','F1-Score','Precision','Recall','Parameter'])

pred=cross_val_predict(DecisionTreeClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='DecisionTreeClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[536 115]
#  [129 420]]
#                         Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier  0.796667  0.796435   0.796422  0.796667   Default

# %%
pred=cross_val_predict(RandomForestClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='RandomForestClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[556  95]
#  [104 445]]
#                         Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier  0.787500  0.787277   0.787241  0.787500   Default
# RandomForestClassifier  0.834167  0.834051   0.834029  0.834167   Default

# %%
pred=cross_val_predict(GradientBoostingClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='GradientBoostingClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[571  80]
#  [107 442]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.787500  0.787277   0.787241  0.787500   Default
# RandomForestClassifier      0.834167  0.834051   0.834029  0.834167   Default
# GradientBoostingClassifier  0.844167  0.843785   0.844269  0.844167   Default

# %%
pred=cross_val_predict(LogisticRegression(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='LogisticRegression'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[465 186]
#  [148 401]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.787500  0.787277   0.787241  0.787500   Default
# RandomForestClassifier      0.834167  0.834051   0.834029  0.834167   Default
# GradientBoostingClassifier  0.844167  0.843785   0.844269  0.844167   Default
# LogisticRegression          0.721667  0.722138   0.724055  0.721667   Default

# %%
pred=cross_val_predict(SVC(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='SVC'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[348 303]
#  [169 380]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.787500  0.787277   0.787241  0.787500   Default
# RandomForestClassifier      0.834167  0.834051   0.834029  0.834167   Default
# GradientBoostingClassifier  0.844167  0.843785   0.844269  0.844167   Default
# LogisticRegression          0.721667  0.722138   0.724055  0.721667   Default
# SVC                         0.606667  0.605495   0.619703  0.606667   Default

# %%
pred=cross_val_predict(KNeighborsClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='KNeighborsClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[430 221]
#  [259 290]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.787500  0.787277   0.787241  0.787500   Default
# RandomForestClassifier      0.834167  0.834051   0.834029  0.834167   Default
# GradientBoostingClassifier  0.844167  0.843785   0.844269  0.844167   Default
# LogisticRegression          0.721667  0.722138   0.724055  0.721667   Default
# SVC                         0.606667  0.605495   0.619703  0.606667   Default
# KNeighborsClassifier        0.600000  0.598502   0.598208  0.600000   Default

# %% [markdown]
# # we can see RandomForest and Gradient boosting scores are best and some what similer.

# %% [markdown]
# # Impute Last Column F15 with mean value and then fit models

# %%
df['F15'].describe()
# Out:
# count    750.000000
# mean       7.683013
# std        1.005117
# min        4.960000
# 25%        6.962500
# 50%        7.690000
# 75%        8.430000
# max       10.040000
# Name: F15, dtype: float64

# %% [markdown]
# # Mean and meadian are almost same for F15, We can use any for imputation

# %%
algo=pd.DataFrame(columns=['Accuracy','F1-Score','Precision','Recall','Parameter'])

# %%
x1=df.drop(['Class'],axis=1)
y1=df['Class']

x, X_test, y, y_test = train_test_split(x1, y1, test_size=0.20, random_state=42)

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(x)
x=imp_mean.transform(x)

X_test=imp_mean.transform(X_test)

print(x)
# Out:
# [[   3.18        -4.29       -41.64      ...    0.94        29.37
#      8.9      ]
#  [   1.62        -5.2        -35.64      ...    0.93        26.82
#      9.32     ]
#  [   1.44        -4.49       -41.64      ...    0.33        36.27
#      7.6932605]
#  ...
#  [   1.28       -10.61       -41.64      ...    0.79        29.16
#      7.6932605]
#  [  23.5          0.31       -80.64      ...   10.2         15.36
#      6.52     ]
#  [  12.3         -3.71      -110.64      ...    7.7         13.14
#      6.53     ]]

# %%
#df['F15'][df['F15'].isnull()]=df['F15'].mean()

# %%
pred=cross_val_predict(DecisionTreeClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='DecisionTreeClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[529 122]
#  [118 431]]
#                         Accuracy  F1-Score  Precision  Recall Parameter
# DecisionTreeClassifier       0.8  0.800055   0.800127     0.8   Default

# %%
pred=cross_val_predict(RandomForestClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='RandomForestClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[577  74]
#  [ 84 465]]
#                         Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier  0.800000  0.800055   0.800127  0.800000   Default
# RandomForestClassifier  0.868333  0.868230   0.868248  0.868333   Default

# %%
pred=cross_val_predict(GradientBoostingClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='GradientBoostingClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[576  75]
#  [103 446]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.800000  0.800055   0.800127  0.800000   Default
# RandomForestClassifier      0.868333  0.868230   0.868248  0.868333   Default
# GradientBoostingClassifier  0.851667  0.851287   0.851847  0.851667   Default

# %%
pred=cross_val_predict(LogisticRegression(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='LogisticRegression'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[484 167]
#  [124 425]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.800000  0.800055   0.800127  0.800000   Default
# RandomForestClassifier      0.868333  0.868230   0.868248  0.868333   Default
# GradientBoostingClassifier  0.851667  0.851287   0.851847  0.851667   Default
# LogisticRegression          0.757500  0.757928   0.760300  0.757500   Default

# %%
pred=cross_val_predict(SVC(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='SVC'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[348 303]
#  [169 380]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.800000  0.800055   0.800127  0.800000   Default
# RandomForestClassifier      0.868333  0.868230   0.868248  0.868333   Default
# GradientBoostingClassifier  0.851667  0.851287   0.851847  0.851667   Default
# LogisticRegression          0.757500  0.757928   0.760300  0.757500   Default
# SVC                         0.606667  0.605495   0.619703  0.606667   Default

# %%
pred=cross_val_predict(KNeighborsClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='KNeighborsClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[430 221]
#  [258 291]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.800000  0.800055   0.800127  0.800000   Default
# RandomForestClassifier      0.868333  0.868230   0.868248  0.868333   Default
# GradientBoostingClassifier  0.851667  0.851287   0.851847  0.851667   Default
# LogisticRegression          0.757500  0.757928   0.760300  0.757500   Default
# SVC                         0.606667  0.605495   0.619703  0.606667   Default
# KNeighborsClassifier        0.600833  0.599388   0.599087  0.600833   Default

# %% [markdown]
# # Performence has improved after mean imputauion for column F15

# %% [markdown]
# # Standard Scaling.

# %%
#x=df.drop(['Class'],axis=1)
scaler = StandardScaler()
scaler.fit(x)
x=scaler.transform(x)

X_test=scaler.transform(X_test)
x
# Out:
# array([[-0.77362596, -0.63667594,  0.78062742, ..., -0.8529201 ,
#         -0.83680266,  0.92848059],
#        [-0.9543418 , -0.99707163,  1.05711884, ..., -0.87004199,
#         -0.83968431,  0.59443233],
#        [-0.97519362, -0.71588378,  0.78062742, ..., -0.80155441,
#         -1.01258338,  1.83237589],
#        ...,
#        [-0.99372858, -3.13964378,  0.78062742, ..., -0.8529201 ,
#         -0.88002743,  0.90097074],
#        [ 1.58031365,  1.18510445, -1.01656676, ...,  1.85233942,
#          1.83160626, -0.90681986],
#        [ 0.28286662, -0.4069732 , -2.39902383, ..., -0.63033545,
#          1.11119348, -1.19763834]])

# %% [markdown]
# # Fit Model on scaled data

# %%
algo=pd.DataFrame(columns=['Accuracy','F1-Score','Precision','Recall','Parameter'])
pred=cross_val_predict(DecisionTreeClassifier(),x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='DecisionTreeClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[526 125]
#  [119 430]]
#                         Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier  0.796667  0.796749    0.79687  0.796667   Default

# %%
pred=cross_val_predict(RandomForestClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='RandomForestClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[574  77]
#  [ 86 463]]
#                         Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier  0.796667  0.796749   0.796870  0.796667   Default
# RandomForestClassifier  0.864167  0.864072   0.864074  0.864167   Default

# %%
pred=cross_val_predict(GradientBoostingClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='GradientBoostingClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[577  74]
#  [106 443]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.796667  0.796749   0.796870  0.796667   Default
# RandomForestClassifier      0.864167  0.864072   0.864074  0.864167   Default
# GradientBoostingClassifier  0.850000  0.849548   0.850322  0.850000   Default

# %%
pred=cross_val_predict(LogisticRegression(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='LogisticRegression'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[555  96]
#  [103 446]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.796667  0.796749   0.796870  0.796667   Default
# RandomForestClassifier      0.864167  0.864072   0.864074  0.864167   Default
# GradientBoostingClassifier  0.850000  0.849548   0.850322  0.850000   Default
# LogisticRegression          0.834167  0.834078   0.834047  0.834167   Default

# %%
pred=cross_val_predict(SVC(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='SVC'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[523 128]
#  [ 97 452]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.796667  0.796749   0.796870  0.796667   Default
# RandomForestClassifier      0.864167  0.864072   0.864074  0.864167   Default
# GradientBoostingClassifier  0.850000  0.849548   0.850322  0.850000   Default
# LogisticRegression          0.834167  0.834078   0.834047  0.834167   Default
# SVC                         0.812500  0.812788   0.814159  0.812500   Default

# %%
pred=cross_val_predict(KNeighborsClassifier(), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='KNeighborsClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,'Default']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[542 109]
#  [186 363]]
#                             Accuracy  F1-Score  Precision    Recall Parameter
# DecisionTreeClassifier      0.796667  0.796749   0.796870  0.796667   Default
# RandomForestClassifier      0.864167  0.864072   0.864074  0.864167   Default
# GradientBoostingClassifier  0.850000  0.849548   0.850322  0.850000   Default
# LogisticRegression          0.834167  0.834078   0.834047  0.834167   Default
# SVC                         0.812500  0.812788   0.814159  0.812500   Default
# KNeighborsClassifier        0.754167  0.751760   0.755743  0.754167   Default

# %% [markdown]
# # performence of SVC and KNN got improved after scaling

# %% [markdown]
# # Hyperparameter Tunning on each model

# %%
param_grid = {"max_depth": [3,5,7,9,11,13],
              "max_features": [1,3,5,7,9,11,13],
              "min_samples_leaf": [1,3,5,7,9,11,13,15],
              "criterion": ["gini", "entropy"]}

clf = DecisionTreeClassifier()
grid = GridSearchCV(clf, param_grid, cv=5)
grid.fit(x,y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8166666666666667
# {'criterion': 'entropy', 'max_depth': 9, 'max_features': 13, 'min_samples_leaf': 5}

# %%
algo=pd.DataFrame(columns=['Accuracy','F1-Score','Precision','Recall','Parameter'])
pred=cross_val_predict(DecisionTreeClassifier(**grid.best_params_), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='DecisionTreeClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,grid.best_params_]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[529 122]
#  [117 432]]
#                         Accuracy  F1-Score  Precision    Recall  \
# DecisionTreeClassifier  0.800833  0.800901   0.800996  0.800833
#
#                                                                 Parameter
# DecisionTreeClassifier  {'criterion': 'entropy', 'max_depth': 9, 'max_...

# %%
param_grid={'n_estimators':[10,50,100,150,200,250],
            'max_features':["auto", "sqrt", "log2"],
            'max_depth':[2,4,8,10]
           }

clf = RandomForestClassifier()
grid = GridSearchCV(clf, param_grid, cv=5)
grid.fit(x,y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8741666666666668
# {'max_depth': 10, 'max_features': 'auto', 'n_estimators': 250}

# %%
pred=cross_val_predict(RandomForestClassifier(**grid.best_params_), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='RandomForestClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,grid.best_params_]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[577  74]
#  [ 83 466]]
#                         Accuracy  F1-Score  Precision    Recall  \
# DecisionTreeClassifier  0.800833  0.800901   0.800996  0.800833
# RandomForestClassifier  0.869167  0.869075   0.869082  0.869167
#
#                                                                 Parameter
# DecisionTreeClassifier  {'criterion': 'entropy', 'max_depth': 9, 'max_...
# RandomForestClassifier  {'max_depth': 10, 'max_features': 'auto', 'n_e...

# %%
param_grid={'n_estimators':[100,200,300,400],
            'max_features':["auto", "sqrt", "log2"],
            'max_depth':[2,4,8,10],
            
           }
         

clf = GradientBoostingClassifier()
grid = GridSearchCV(clf, param_grid, cv=5)
grid.fit(x,y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8858333333333335
# {'max_depth': 8, 'max_features': 'sqrt', 'n_estimators': 400}

# %%
pred=cross_val_predict(GradientBoostingClassifier(**grid.best_params_), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='GradientBoostingClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,grid.best_params_]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[589  62]
#  [ 81 468]]
#                             Accuracy  F1-Score  Precision    Recall  \
# DecisionTreeClassifier      0.800833  0.800901   0.800996  0.800833
# RandomForestClassifier      0.869167  0.869075   0.869082  0.869167
# GradientBoostingClassifier  0.880833  0.880641   0.880895  0.880833
#
#                                                                     Parameter
# DecisionTreeClassifier      {'criterion': 'entropy', 'max_depth': 9, 'max_...
# RandomForestClassifier      {'max_depth': 10, 'max_features': 'auto', 'n_e...
# GradientBoostingClassifier  {'max_depth': 8, 'max_features': 'sqrt', 'n_es...

# %%
param_grid={'kernel': ('linear', 'rbf','poly'),'C':[1.5, 10],'gamma': [1e-7, 1e-4]}

clf = SVC()
grid = GridSearchCV(clf, param_grid, cv=5)
grid.fit(x,y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.865
# {'C': 10, 'gamma': 1e-07, 'kernel': 'linear'}

# %%
pred=cross_val_predict(SVC(**grid.best_params_), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='SVC'

algo.loc[model]=[accuracy,f1,precision,recall,grid.best_params_]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[578  73]
#  [ 84 465]]
#                             Accuracy  F1-Score  Precision    Recall  \
# DecisionTreeClassifier      0.800833  0.800901   0.800996  0.800833
# RandomForestClassifier      0.869167  0.869075   0.869082  0.869167
# GradientBoostingClassifier  0.880833  0.880641   0.880895  0.880833
# SVC                         0.869167  0.869053   0.869086  0.869167
#
#                                                                     Parameter
# DecisionTreeClassifier      {'criterion': 'entropy', 'max_depth': 9, 'max_...
# RandomForestClassifier      {'max_depth': 10, 'max_features': 'auto', 'n_e...
# GradientBoostingClassifier  {'max_depth': 8, 'max_features': 'sqrt', 'n_es...
# SVC                             {'C': 10, 'gamma': 1e-07, 'kernel': 'linear'}

# %%
param_grid={'C':np.logspace(-3, 3, 5)}

clf = LogisticRegression()
grid = GridSearchCV(clf, param_grid, cv=5)
grid.fit(x,y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.8783333333333335
# {'C': 1000.0}

# %%
pred=cross_val_predict(LogisticRegression(**grid.best_params_), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='LogisticRegression'

algo.loc[model]=[accuracy,f1,precision,recall,grid.best_params_]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[578  73]
#  [ 79 470]]
#                             Accuracy  F1-Score  Precision    Recall  \
# DecisionTreeClassifier      0.800833  0.800901   0.800996  0.800833
# RandomForestClassifier      0.869167  0.869075   0.869082  0.869167
# GradientBoostingClassifier  0.880833  0.880641   0.880895  0.880833
# SVC                         0.869167  0.869053   0.869086  0.869167
# LogisticRegression          0.873333  0.873276   0.873262  0.873333
#
#                                                                     Parameter
# DecisionTreeClassifier      {'criterion': 'entropy', 'max_depth': 9, 'max_...
# RandomForestClassifier      {'max_depth': 10, 'max_features': 'auto', 'n_e...
# GradientBoostingClassifier  {'max_depth': 8, 'max_features': 'sqrt', 'n_es...
# SVC                             {'C': 10, 'gamma': 1e-07, 'kernel': 'linear'}
# LogisticRegression                                              {'C': 1000.0}

# %%
param_grid={'leaf_size': list(range(1,5)), 'n_neighbors': list(range(1,10)), 'p':[1,2]}

clf = KNeighborsClassifier()
grid = GridSearchCV(clf, param_grid, cv=5)
grid.fit(x,y)

print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.7825
# {'leaf_size': 1, 'n_neighbors': 7, 'p': 1}

# %%
pred=cross_val_predict(KNeighborsClassifier(**grid.best_params_), x, y, cv=10)

accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

model='KNeighborsClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,grid.best_params_]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
algo
# Out:
# confusion_matrics
#  [[555  96]
#  [152 397]]
#                             Accuracy  F1-Score  Precision    Recall  \
# DecisionTreeClassifier      0.800833  0.800901   0.800996  0.800833
# RandomForestClassifier      0.869167  0.869075   0.869082  0.869167
# GradientBoostingClassifier  0.880833  0.880641   0.880895  0.880833
# SVC                         0.869167  0.869053   0.869086  0.869167
# LogisticRegression          0.873333  0.873276   0.873262  0.873333
# KNeighborsClassifier        0.793333  0.792041   0.794279  0.793333
#
#                                                                     Parameter
# DecisionTreeClassifier      {'criterion': 'entropy', 'max_depth': 9, 'max_...
# RandomForestClassifier      {'max_depth': 10, 'max_features': 'auto', 'n_e...
# GradientBoostingClassifier  {'max_depth': 8, 'max_features': 'sqrt', 'n_es...
# SVC                             {'C': 10, 'gamma': 1e-07, 'kernel': 'linear'}
# ...

# %% [markdown]
# # Gradient boosting is best modal after hyper parameter tunning on training set. Few others too are some what giving equal score

# %% [markdown]
# # Lets test performence of GradientBoostingClassifier,RandomForestClassifier,LogisticRegression on test set

# %%
algo=pd.DataFrame(columns=['Accuracy','F1-Score','Precision','Recall','Parameter'])

rand=RandomForestClassifier(max_depth= 10, max_features= 'auto', n_estimators= 200)
rand.fit(x,y)
pred=rand.predict(X_test)

accuracy=accuracy_score(y_test,pred)
f1=f1_score(y_test, pred, average='weighted')
precision=precision_score(y_test, pred, average='weighted')
recall=recall_score(y_test, pred, average='weighted')
confusion=confusion_matrix(y_test,pred)

model='RandomForestClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,"max_depth= 10, max_features= 'auto', n_estimators= 200"]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nRandomForestClassifier confusion_matrics\n",confusion)
algo

#---------------------------------------------------------------
grad=GradientBoostingClassifier(max_depth= 8, max_features= 'sqrt', n_estimators= 400)
grad.fit(x,y)
pred=grad.predict(X_test)

accuracy=accuracy_score(y_test,pred)
f1=f1_score(y_test, pred, average='weighted')
precision=precision_score(y_test, pred, average='weighted')
recall=recall_score(y_test, pred, average='weighted')
confusion=confusion_matrix(y_test,pred)

model='GradientBoostingClassifier'

algo.loc[model]=[accuracy,f1,precision,recall,"max_depth= 8, max_features= 'sqrt', n_estimators= 400"]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nGradientBoostingClassifier confusion_matrics\n",confusion)
algo

#------------------------------------------------------------------
grad=LogisticRegression(C= 1000.0)
grad.fit(x,y)
pred=grad.predict(X_test)

accuracy=accuracy_score(y_test,pred)
f1=f1_score(y_test, pred, average='weighted')
precision=precision_score(y_test, pred, average='weighted')
recall=recall_score(y_test, pred, average='weighted')
confusion=confusion_matrix(y_test,pred)

model='LogisticRegression'

algo.loc[model]=[accuracy,f1,precision,recall,'C= 1000.0']

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nLogisticRegression confusion_matrics\n",confusion)
algo
# Out:
# RandomForestClassifier confusion_matrics
#  [[144  14]
#  [ 30 112]]
#
# GradientBoostingClassifier confusion_matrics
#  [[148  10]
#  [ 24 118]]
#
# LogisticRegression confusion_matrics
#  [[146  12]
#  [ 31 111]]
#                             Accuracy  F1-Score  Precision    Recall  \
# RandomForestClassifier      0.853333  0.852489   0.856603  0.853333
# GradientBoostingClassifier  0.886667  0.886132   0.889532  0.886667
# LogisticRegression          0.856667  0.855593   0.861580  0.856667
#
#                                                                     Parameter
# RandomForestClassifier      max_depth= 10, max_features= 'auto', n_estimat...
# GradientBoostingClassifier  max_depth= 8, max_features= 'sqrt', n_estimato...
# LogisticRegression                                                  C= 1000.0

# %% [markdown]
# # Gradient bossting is the best model so Far

# %% [markdown]
# # Try Deep Learning Model

# %%
import tensorflow as tf
import math
from keras.models import Sequential 
from keras.layers import Dense, Activation, Dropout 
from keras.optimizers import Adam,SGD
from keras.callbacks import TensorBoard,EarlyStopping

# %%
from sklearn.model_selection import train_test_split
import math
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
from keras.initializers import RandomNormal
fan_in=X_train.shape[1]
relu_std=math.sqrt(2/fan_in)

# %%
import math
import numpy as np

model_2 = Sequential()
model_2.add(Dense(35, input_dim=X_train.shape[1], activation='relu',kernel_initializer=RandomNormal(mean=0.0, stddev=relu_std, seed=None)))
#model_1.add(Dropout(0.5))
model_2.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate=0.01,momentum=0.9)
model_2.compile(optimizer=opt, loss='binary_crossentropy',metrics='accuracy')
model_2.summary()
early_stopping_cb = EarlyStopping(patience=50,restore_best_weights=True)
run_logdir=r"C:\Users\Deepak Tripathi\Desktop\rossman\log"
history = model_2.fit(np.array(X_train), y_train, batch_size=len(X_train),validation_data=(X_val, y_val) ,epochs=500000, verbose=1,callbacks=[early_stopping_cb])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 35)                560
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 36
# ...
# Total params: 596
# Trainable params: 596
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500000
# 1/1 [==============================] - 0s 348ms/step - loss: 0.9080 - accuracy: 0.4306 - val_loss: 0.8816 - val_accuracy: 0.4167
# Epoch 2/500000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9040 - accuracy: 0.4287 - val_loss: 0.8738 - val_accuracy: 0.4083
# Epoch 3/500000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.8966 - accuracy: 0.4176 - val_loss: 0.8633 - val_accuracy: 0.4167
# Epoch 4/500000
# ...

# %%
pred=model_2.predict(X_val)


pred=list(map(lambda x: True if x>0.5 else False,pred))

model='MLP'

accuracy=accuracy_score(y_val,pred)
f1=f1_score(y_val, pred, average='weighted')
precision=precision_score(y_val, pred, average='weighted')
recall=recall_score(y_val, pred, average='weighted')
confusion=confusion_matrix(y_val,pred)

[accuracy,f1,precision,recall,['40 Nuerons','Relu','Sigmoid']]

# algo.loc[model]=[accuracy,f1,precision,recall,['40 Nuerons','Relu','Sigmoid']]
# algo
# Out:
# [0.8833333333333333,
#  0.8832685005094009,
#  0.8851712614870509,
#  0.8833333333333333,
#  ['40 Nuerons', 'Relu', 'Sigmoid']]

# %%
pred=model_2.predict(X_test)


pred=list(map(lambda x: True if x>0.5 else False,pred))

model='MLP'

accuracy=accuracy_score(y_test,pred)
f1=f1_score(y_test, pred, average='weighted')
precision=precision_score(y_test, pred, average='weighted')
recall=recall_score(y_test, pred, average='weighted')
confusion=confusion_matrix(y_test,pred)

algo.loc[model]=[accuracy,f1,precision,recall,['40 Nuerons','Relu','Sigmoid']]
algo
# Out:
#                             Accuracy  F1-Score  Precision    Recall  \
# RandomForestClassifier      0.853333  0.852489   0.856603  0.853333
# GradientBoostingClassifier  0.886667  0.886132   0.889532  0.886667
# LogisticRegression          0.856667  0.855593   0.861580  0.856667
# MLP                         0.903333  0.902828   0.906936  0.903333
#
#                                                                     Parameter
# RandomForestClassifier      max_depth= 10, max_features= 'auto', n_estimat...
# GradientBoostingClassifier  max_depth= 8, max_features= 'sqrt', n_estimato...
# LogisticRegression                                                  C= 1000.0
# MLP                                               [40 Nuerons, Relu, Sigmoid]

# %% [markdown]
# # create a model to predict F15 missing values

# %%
df=pd.read_csv(r"C:\Users\Deepak Tripathi\Desktop\assignment machine learning\part2\CE802_P2_Data.csv")

# %%
null_df=df[df['F15'].isnull()]
null_df.drop(['F15'],axis=1,inplace=True)
null_df.head()
# Out:
#       F1    F2     F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 0   3.20 -4.91 -41.64 -21.63   8.41   2  5.42 -84.01  -9.40   76.72 -0.42
# 2  12.60  0.41 -50.64 -15.51  16.34  20 -4.00  25.99 -15.08  450.72 -3.60
# 4   2.74 -3.86 -35.64 -23.91   8.67   2  2.80 -53.01 -19.22   24.72  0.59
# 7  13.60 -1.86 -80.64 -14.85  12.69  20  0.08   0.99 -12.34  350.72  0.95
# 8   2.08 -5.17 -35.64 -24.99   8.61   2  1.36 -66.01 -11.74   20.72  3.26
#
#    F12   F13    F14  Class
# 0   36  0.33  30.60  False
# 2  525  5.10  21.78  False
# 4   33  0.85  25.08   True
# 7  420  5.60  19.17  False
# 8   21  0.56  26.82   True

# %%
not_null_df=df[~df['F15'].isnull()]
not_null_df.head()
# Out:
#        F1    F2      F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 1    3.98 -5.25  -47.64 -23.43   8.66   2  4.32 -83.01 -11.16    2.72  0.50
# 3   14.70  1.09  -50.64  -4.74  15.09  20 -8.16  10.99 -13.12  190.72 -5.71
# 5    0.64 -3.71  -47.64 -18.99   8.61   2  0.94 -71.01 -10.88   50.72 -0.06
# 6   11.00 -0.36 -110.64  -4.08  13.19  20 -6.32 -99.01  -9.94   -9.28 -5.31
# 11   0.72 -4.50  -41.64 -28.98   8.90   2  1.08 -77.01 -10.06   -3.28 -0.93
#
#     F12   F13    F14   F15  Class
# 1   111  0.84  39.42  9.26   True
# 3   660  7.25  15.78  6.57  False
# 5   132  0.56  26.22  8.43   True
# 6   975  9.25  10.89  8.92   True
# 11   21  0.23  29.52  7.81   True

# %%
df=not_null_df.copy()
df.columns
# Out:
# Index(['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11',
#        'F12', 'F13', 'F14', 'F15', 'Class'],
#       dtype='object')

# %%
x=df[['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11',
       'F12', 'F13', 'F14']]

y=df['F15']

# %%
x.head()
# Out:
#        F1    F2      F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 1    3.98 -5.25  -47.64 -23.43   8.66   2  4.32 -83.01 -11.16    2.72  0.50
# 3   14.70  1.09  -50.64  -4.74  15.09  20 -8.16  10.99 -13.12  190.72 -5.71
# 5    0.64 -3.71  -47.64 -18.99   8.61   2  0.94 -71.01 -10.88   50.72 -0.06
# 6   11.00 -0.36 -110.64  -4.08  13.19  20 -6.32 -99.01  -9.94   -9.28 -5.31
# 11   0.72 -4.50  -41.64 -28.98   8.90   2  1.08 -77.01 -10.06   -3.28 -0.93
#
#     F12   F13    F14
# 1   111  0.84  39.42
# 3   660  7.25  15.78
# 5   132  0.56  26.22
# 6   975  9.25  10.89
# 11   21  0.23  29.52

# %%
mi_r=StandardScaler()
mi_r.fit(x)
minx=mi_r.transform(x)
minx[:5]
# Out:
# array([[-7.19056930e-01, -1.07714148e+00,  5.46751976e-01,
#         -1.22968831e+00, -9.40892005e-01, -1.02923901e+00,
#          1.11880364e+00, -4.58388470e-01, -5.78993114e-04,
#         -1.00888758e+00,  1.02271122e+00, -6.35968505e-01,
#         -9.17612131e-01,  2.34824002e+00],
#        [ 5.15781618e-01,  1.44855419e+00,  4.05933301e-01,
#          1.28106951e+00,  1.09333798e+00,  9.67129755e-01,
#         -1.33332278e+00,  1.84384044e+00, -8.87162199e-01,
#          3.20779929e-01, -1.48869172e+00,  9.15546405e-01,
#          9.28773015e-01, -7.87188972e-01],
#        [-1.10379208e+00, -4.63644424e-01,  5.46751976e-01,
#         -6.33232197e-01, -9.56710278e-01, -1.02923901e+00,
#          4.54686066e-01, -1.64486908e-01,  1.26075751e-01,
#         -6.69398003e-01,  7.96240099e-01, -5.76620940e-01,
#         -9.98265460e-01,  5.97492865e-01],
#        [ 8.95780143e-02,  8.70910858e-01, -2.41044020e+00,
#          1.36973190e+00,  4.92243583e-01,  9.67129755e-01,
# ...

# %%
minx.shape
# Out:
# (750, 14)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,r2_score

pred = cross_val_predict(RandomForestRegressor(), minx, y, cv=10)
print('RandomForestRegressor')
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
print('-'*50)
print('GradientBoostingRegressor')
pred = cross_val_predict(GradientBoostingRegressor(), minx, y, cv=10)
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
print('-'*50)
print('LinearRegression')
pred = cross_val_predict(LinearRegression(), minx, y, cv=10)
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
print('-'*50)
print('SVR')
pred = cross_val_predict(SVR(kernel='linear'), minx, y, cv=10)
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
# Out:
# RandomForestRegressor
# RMSE= 0.5328789574133335
# R2= 0.4718285221978382
# --------------------------------------------------
# GradientBoostingRegressor
# RMSE= 0.516506200908738
# R2= 0.4880566409449244
# --------------------------------------------------
# LinearRegression
# RMSE= 0.6263655012373482
# R2= 0.37916784322145536
# --------------------------------------------------
# SVR
# RMSE= 0.6292826704922106
# R2= 0.3762764443870581

# %%
pred = cross_val_predict(GradientBoostingRegressor(max_depth= 8, max_features= 'sqrt', n_estimators= 400), minx, y, cv=10)
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
print('-'*50)

pred = cross_val_predict(RandomForestRegressor(max_depth= 10, max_features= 'auto', n_estimators= 200), minx, y, cv=10)
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
print('-'*50)

pred = cross_val_predict(SVR(C= 10, gamma= 1e-07, kernel= 'linear'), minx, y, cv=10)
print('RMSE=',mean_squared_error(y,pred))
print('R2=',r2_score(y,pred))
print('-'*50)
# Out:
# RMSE= 0.49669615127735045
# R2= 0.5076916875977957
# --------------------------------------------------
# RMSE= 0.540535728027058
# R2= 0.4642393918822528
# --------------------------------------------------
# RMSE= 0.6285543845700622
# R2= 0.37699829659460415
# --------------------------------------------------

# %% [markdown]
# # Gradient boosting is the best to impute missing values

# %%
clf=GradientBoostingRegressor(max_depth= 8, max_features= 'sqrt', n_estimators= 400)
clf.fit(minx,y)
# Out:
# GradientBoostingRegressor(max_depth=8, max_features='sqrt', n_estimators=400)

# %%
null_df1=null_df.drop(['Class'],axis=1)
x_test=mi_r.transform(null_df1)
x_test[:5]
# Out:
# array([[-0.80890526, -0.94169408,  0.82838933, -0.98788178, -1.01998337,
#         -1.02923901,  1.33493658, -0.48288027,  0.79553654, -0.48550782,
#          0.65065152, -0.84792409, -1.06451641,  1.1784226 ],
#        [ 0.27388228,  1.17765939,  0.4059333 , -0.16573957,  1.48879482,
#          0.96712976, -0.51594731,  2.21121739, -1.7737454 ,  2.1596818 ,
#         -0.6353809 ,  0.53402635,  0.30947067,  0.00860519],
#        [-0.86189273, -0.52340063,  1.11002668, -1.29417005, -0.93772835,
#         -1.02923901,  0.82014722,  0.27636544, -3.64642626, -0.85328819,
#          1.05910836, -0.85640232, -0.91473165,  0.44629198],
#        [ 0.38907244,  0.27334879, -1.00225345, -0.07707718,  0.33406085,
#          0.96712976,  0.28570941,  1.59892247, -0.53433827,  1.45241185,
#          1.20469694,  0.23728852,  0.45349447, -0.33756527],
#        [-0.93791824, -1.0452715 ,  1.11002668, -1.43925397, -0.95671028,
# ...

# %%
pred=clf.predict(x_test)

# %%
null_df['F15']=pred

# %%
null_df=null_df[['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11',
       'F12', 'F13', 'F14', 'F15','Class']]

# %%
null_df.head()
# Out:
#       F1    F2     F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 0   3.20 -4.91 -41.64 -21.63   8.41   2  5.42 -84.01  -9.40   76.72 -0.42
# 2  12.60  0.41 -50.64 -15.51  16.34  20 -4.00  25.99 -15.08  450.72 -3.60
# 4   2.74 -3.86 -35.64 -23.91   8.67   2  2.80 -53.01 -19.22   24.72  0.59
# 7  13.60 -1.86 -80.64 -14.85  12.69  20  0.08   0.99 -12.34  350.72  0.95
# 8   2.08 -5.17 -35.64 -24.99   8.61   2  1.36 -66.01 -11.74   20.72  3.26
#
#    F12   F13    F14       F15  Class
# 0   36  0.33  30.60  7.481159  False
# 2  525  5.10  21.78  6.609182  False
# 4   33  0.85  25.08  8.519742   True
# 7  420  5.60  19.17  6.873704  False
# 8   21  0.56  26.82  8.393593   True

# %%
null_df.shape
# Out:
# (750, 16)

# %%
new_df=pd.concat([null_df, not_null_df], axis=0) 
new_df.head()
# Out:
#       F1    F2     F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 0   3.20 -4.91 -41.64 -21.63   8.41   2  5.42 -84.01  -9.40   76.72 -0.42
# 2  12.60  0.41 -50.64 -15.51  16.34  20 -4.00  25.99 -15.08  450.72 -3.60
# 4   2.74 -3.86 -35.64 -23.91   8.67   2  2.80 -53.01 -19.22   24.72  0.59
# 7  13.60 -1.86 -80.64 -14.85  12.69  20  0.08   0.99 -12.34  350.72  0.95
# 8   2.08 -5.17 -35.64 -24.99   8.61   2  1.36 -66.01 -11.74   20.72  3.26
#
#    F12   F13    F14       F15  Class
# 0   36  0.33  30.60  7.481159  False
# 2  525  5.10  21.78  6.609182  False
# 4   33  0.85  25.08  8.519742   True
# 7  420  5.60  19.17  6.873704  False
# 8   21  0.56  26.82  8.393593   True

# %%
new_df.shape
# Out:
# (1500, 16)

# %%
new_df=new_df.sample(frac=1)
new_df.head()
# Out:
#          F1    F2     F3     F4     F5  F6    F7      F8     F9     F10   F11  \
# 1456  16.30  0.85 -35.64  -5.04  15.14  20 -8.40  -44.01 -12.12  270.72 -5.41
# 1362   0.36 -4.73 -41.64 -17.31   8.88   0  2.06  -87.01 -15.32   18.72 -0.77
# 147   22.00 -0.89 -80.64  -8.28  14.69  20 -7.06 -144.01 -11.78  260.72 -5.21
# 420   21.00  0.22 -50.64  -6.60  16.84  20 -7.94  -39.01 -11.96  440.72 -4.20
# 20     2.84 -4.11 -41.64 -25.89   8.20   2  1.46  -70.01 -10.60   30.72  2.54
#
#       F12   F13    F14       F15  Class
# 1456   15  7.70  13.77  9.060000   True
# 1362   69  0.13  25.17  7.120000   True
# 147   930  9.30  11.58  8.190000   True
# 420   825  6.70  12.45  8.300002  False
# 20     72  0.32  32.28  7.468866  False

# %%
new_df.shape
# Out:
# (1500, 16)

# %% [markdown]
# # Now apply Gradient Booting with best params on this new imputed data

# %%
x=new_df.drop(['Class'],axis=1)
y=new_df['Class']

mi_n=StandardScaler()
mi_n.fit(x)
minx=mi_n.transform(x)
minx[:5]
# Out:
# array([[-1.10523042, -0.43752054,  0.78776813, -0.60204523, -0.85847736,
#         -0.97777869,  0.93743312, -0.06008704,  0.01114324, -0.80463465,
#          0.44670099, -0.91243655, -0.98849895,  2.24277285,  0.16096188],
#        [-0.88782745, -1.61871733,  0.50831863, -0.61796239, -1.02904749,
#         -0.97777869,  0.55226201, -0.6076906 ,  0.27273572, -0.5945302 ,
#          1.25781384, -0.6481467 , -0.89323669,  0.47259762,  0.73250408],
#        [ 0.12286505,  1.46420629, -2.42590107,  0.8941675 ,  1.07780949,
#          1.02070917,  0.45007375, -2.10115485,  0.93122715,  0.14783882,
#         -0.55313613,  1.03137267,  1.45656574, -1.38373658,  1.6777431 ],
#        [ 0.70106443,  1.15709513, -1.02865359,  1.37168221,  0.69876476,
#          1.02070917,  0.60728645,  0.01458617, -1.88314716, -0.62254413,
#         -1.37629521,  0.26407955,  1.05242281, -1.02735174,  0.51802169],
#        [ 2.03092299,  1.04685009,  0.36859388,  1.26822069,  0.825113  ,
# ...

# %%
x, X_test, y, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
pred = cross_val_predict(GradientBoostingClassifier(max_depth= 8, max_features= 'sqrt',n_estimators= 400),x, y, cv=10)
accuracy=accuracy_score(y,pred)
f1=f1_score(y, pred, average='weighted')
precision=precision_score(y, pred, average='weighted')
recall=recall_score(y, pred, average='weighted')
confusion=confusion_matrix(y,pred)

[accuracy,f1,precision,recall]

# print("\naccuracy_score=",accuracy)
# print("\nf1_scores=",f1)
print("\nconfusion_matrics\n",confusion)
[accuracy,f1,precision,recall]
#algo
# Out:
# confusion_matrics
#  [[592  63]
#  [ 87 458]]
# [0.875, 0.8747173083251993, 0.8751441659434812, 0.875]

# %% [markdown]
# # try applyting MLP as well on this new data

# %%
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
import math
import numpy as np

model_1 = Sequential()
model_1.add(Dense(55, input_dim=X_train.shape[1], activation='relu',kernel_initializer=RandomNormal(mean=0.0, stddev=relu_std, seed=None)))
#model_1.add(Dropout(0.5))
model_1.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate=0.01,momentum=0.9)
model_1.compile(optimizer=opt, loss='binary_crossentropy',metrics='accuracy')
model_1.summary()
early_stopping_cb = EarlyStopping(patience=50,restore_best_weights=True)
run_logdir=r"C:\Users\Deepak Tripathi\Desktop\rossman\log"
history = model_1.fit(np.array(X_train), y_train, batch_size=len(X_train),validation_data=(X_val, y_val) ,epochs=500000, verbose=1,callbacks=[early_stopping_cb])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 55)                880
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 56
# ...
# Total params: 936
# Trainable params: 936
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500000
# 1/1 [==============================] - 0s 147ms/step - loss: 41.6237 - accuracy: 0.4677 - val_loss: 1397.1224 - val_accuracy: 0.6083
# Epoch 2/500000
# 1/1 [==============================] - 0s 20ms/step - loss: 1542.6587 - accuracy: 0.5302 - val_loss: 12.6712 - val_accuracy: 0.6083
# Epoch 3/500000
# 1/1 [==============================] - 0s 19ms/step - loss: 11.3764 - accuracy: 0.5302 - val_loss: 2.0085 - val_accuracy: 0.6000
# Epoch 4/500000
# ...

# %% [markdown]
# # We have not observed any improvement in performence after model based imputation

# %% [markdown]
# # Final/Best Model

# %% [markdown]
# # MLP with Mean Imputaion and Standard Scaling

# %% [markdown]
# Lets again train this model on whole train data and then use it for predicting test data

# %%
df=pd.read_csv(r"C:\Users\Deepak Tripathi\Desktop\assignment machine learning\part2\CE802_P2_Data.csv")

x=df.drop(['Class'],axis=1)
y=df['Class']

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(x)
x=imp_mean.transform(x)   #use it on test data as well

scaler = StandardScaler()
scaler.fit(x)
x=scaler.transform(x)   #use it on test data as well

# %%
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
import math
import numpy as np

model_2 = Sequential()
model_2.add(Dense(35, input_dim=X_train.shape[1], activation='relu',kernel_initializer=RandomNormal(mean=0.0, stddev=relu_std, seed=None)))
#model_1.add(Dropout(0.5))
model_2.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate=0.01,momentum=0.9)
model_2.compile(optimizer=opt, loss='binary_crossentropy',metrics='accuracy')
model_2.summary()
early_stopping_cb = EarlyStopping(patience=50,restore_best_weights=True)
run_logdir=r"C:\Users\Deepak Tripathi\Desktop\rossman\log"
history = model_2.fit(np.array(X_train), y_train, batch_size=len(X_train),validation_data=(X_val, y_val) ,epochs=500000, verbose=1,callbacks=[early_stopping_cb])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_14 (Dense)             (None, 35)                560
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 36
# ...
# Total params: 596
# Trainable params: 596
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500000
# 1/1 [==============================] - 0s 157ms/step - loss: 1.2879 - accuracy: 0.4267 - val_loss: 1.3045 - val_accuracy: 0.3933
# Epoch 2/500000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2525 - accuracy: 0.4289 - val_loss: 1.2350 - val_accuracy: 0.3933
# Epoch 3/500000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1873 - accuracy: 0.4311 - val_loss: 1.1411 - val_accuracy: 0.4067
# Epoch 4/500000
# ...

# %%
# df=pd.read_csv(r"C:\Users\Deepak Tripathi\Desktop\assignment machine learning\part2\CE802_P2_Data.csv")

# x=df.drop(['Class'],axis=1)
# y=df['Class']


# imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
# imp_mean.fit(x)
# x=imp_mean.transform(x)   #use it on test data as well

# scaler = StandardScaler()
# scaler.fit(x)
# x=scaler.transform(x)   #use it on test data as well


# clf=GradientBoostingClassifier(max_depth= 4, max_features= 'log2',n_estimators= 300)
# clf.fit(x,y)

# %% [markdown]
# # Predict Test Data provided by company

# %%
df_test=pd.read_csv(r"C:\Users\Deepak Tripathi\Desktop\assignment machine learning\part2\CE802_P2_Test.csv")

# %%
df_test.drop(['Class'],axis=1,inplace=True)

# %%
df_test.head()
# Out:
#       F1    F2     F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 0  19.10  0.05 -50.64  -9.21  17.09  20 -7.08 -34.01 -11.32  310.72 -5.48
# 1  14.60  1.32 -50.64  -2.64  17.04  20  4.74 -64.01  -9.72  170.72 -6.28
# 2  12.00  0.29 -80.64  -3.90  15.64  20 -7.62 -39.01  -7.52   60.72 -4.79
# 3   2.00 -5.10 -47.64 -25.92   8.10   2  4.42 -82.01 -17.14   14.72 -0.33
# 4   1.26 -3.43 -35.64 -18.60   8.87   2  1.88 -60.01 -14.36   14.72 -1.12
#
#    F12   F13    F14   F15
# 0  900  5.45  10.38   NaN
# 1  585  7.20  13.14   NaN
# 2   45  5.05  13.38  7.33
# 3  174  0.95  37.08  6.93
# 4  117  0.67  38.58  8.18

# %%
x_test=imp_mean.transform(df_test)
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 1.05954804,  1.07047403,  0.36859388, ...,  0.4606421 ,
#         -1.54038925,  0.        ],
#        [ 0.5391686 ,  1.570514  ,  0.36859388, ...,  0.96582076,
#         -1.1800881 ,  0.        ],
#        [ 0.23850493,  1.16496977, -1.02865359, ...,  0.3451727 ,
#         -1.14875756, -0.49702621],
#        ...,
#        [ 0.62011652,  0.23182431, -2.42590107, ...,  0.57611151,
#         -0.37724314,  0.        ],
#        [-0.98496495, -1.50453497,  0.78776813, ..., -0.94231119,
#          0.44909972, -1.44035478],
#        [ 1.03642006,  0.96022899, -2.42590107, ...,  0.72044827,
#         -0.9255275 ,  0.        ]])

# %%
y_pred=model_2.predict(x_test)
y_pred=pred=list(map(lambda x: True if x>0.5 else False,y_pred))

# %%
df_test['Class']=y_pred
df_test.head()
# Out:
#       F1    F2     F3     F4     F5  F6    F7     F8     F9     F10   F11  \
# 0  19.10  0.05 -50.64  -9.21  17.09  20 -7.08 -34.01 -11.32  310.72 -5.48
# 1  14.60  1.32 -50.64  -2.64  17.04  20  4.74 -64.01  -9.72  170.72 -6.28
# 2  12.00  0.29 -80.64  -3.90  15.64  20 -7.62 -39.01  -7.52   60.72 -4.79
# 3   2.00 -5.10 -47.64 -25.92   8.10   2  4.42 -82.01 -17.14   14.72 -0.33
# 4   1.26 -3.43 -35.64 -18.60   8.87   2  1.88 -60.01 -14.36   14.72 -1.12
#
#    F12   F13    F14   F15  Class
# 0  900  5.45  10.38   NaN  False
# 1  585  7.20  13.14   NaN   True
# 2   45  5.05  13.38  7.33   True
# 3  174  0.95  37.08  6.93  False
# 4  117  0.67  38.58  8.18   True

# %%
df_test.tail()
# Out:
#          F1    F2      F3     F4     F5  F6    F7      F8     F9     F10  \
# 1495  27.00  1.04  -80.64  -3.87  13.69  20 -8.58  -59.01 -11.50  120.72
# 1496  29.50  0.09  -50.64  -3.54  14.99  20 -8.90  -49.01  -9.54  240.72
# 1497  15.30 -2.08 -110.64  -7.62  13.84  20 -6.60 -154.01  -7.14  220.72
# 1498   1.42 -6.49  -41.64 -20.10   8.22   2  1.02  -77.01 -13.32   -7.28
# 1499  18.90 -0.23 -110.64 -11.07  14.34  20 -6.22 -104.01  -9.16  400.72
#
#        F11   F12   F13    F14   F15  Class
# 1495 -5.60   750  9.00  21.87  8.11   True
# 1496 -3.99  1050  8.70  13.89   NaN   True
# 1497 -1.13   690  5.85  19.29   NaN  False
# 1498 -0.28    15  0.59  25.62  6.66  False
# 1499 -3.87   495  6.35  15.09   NaN  False

# %%
df_test.to_csv("CE802_P2_Test.csv")

# %%
model_2.save('Insurence_Classification_Modal')
# Out:
# WARNING:tensorflow:From C:\Users\Deepak Tripathi\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Deepak Tripathi\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: Insurence_Classification_Modal\assets
